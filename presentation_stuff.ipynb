# %%
import lingtypology

# %%
w = lingtypology.datasets.Wals('1a')
w.get_df().head(10)
# Out:
# Citation for feature 1A:
# Ian Maddieson. 2013. Consonant Inventories.
# In: Dryer, Matthew S. & Haspelmath, Martin (eds.)
# The World Atlas of Language Structures Online.
# Leipzig: Max Planck Institute for Evolutionary Anthropology.
# (Available online at http://wals.info/chapter/1, Accessed on 2019-06-15.)
#   wals_code           language                genus               family  \
# 0       kiw   Kiwai (Southern)              Kiwaian              Kiwaian
# 1       xoo               !Xóõ                   Tu                   Tu
# 2       ani              //Ani           Khoe-Kwadi           Khoe-Kwadi
# 3       abi             Abipón     South Guaicuruan           Guaicuruan
# 4       abk             Abkhaz  Northwest Caucasian  Northwest Caucasian
# 5       acm           Achumawi          Palaihnihan                Hokan
# 6       ach               Aché         Tupi-Guaraní               Tupian
# 7       aco              Acoma              Keresan              Keresan
# 8       adz             Adzera              Oceanic         Austronesian
# 9       agh              Aghem              Bantoid          Niger-Congo
#
#                        coordinates   _1A_area                  _1A  _1A_num  \
# 0                    (-8.0, 143.5)  Phonology             1. Small        1
# 1                    (-24.0, 21.5)  Phonology             5. Large        5
# 2  (-18.9166666667, 21.9166666667)  Phonology             5. Large        5
# 3                   (-29.0, -61.0)  Phonology  2. Moderately small        2
# 4            (43.0833333333, 41.0)  Phonology             5. Large        5
# 5                   (41.5, -121.0)  Phonology  2. Moderately small        2
# 6         (-25.25, -55.1666666667)  Phonology             1. Small        1
# 7  (34.9166666667, -107.583333333)  Phonology             5. Large        5
# 8                  (-6.25, 146.25)  Phonology  2. Moderately small        2
# 9        (6.666666666669999, 10.0)  Phonology           3. Average        3
#
#            _1A_desc
# 0             Small
# 1             Large
# 2             Large
# 3  Moderately small
# 4             Large
# 5  Moderately small
# 6             Small
# 7             Large
# 8  Moderately small
# 9           Average

# %%
df = w.get_df().head(10)
print(df.to_latex())
# Out:
# Citation for feature 1A:
# Ian Maddieson. 2013. Consonant Inventories.
# In: Dryer, Matthew S. & Haspelmath, Martin (eds.)
# The World Atlas of Language Structures Online.
# Leipzig: Max Planck Institute for Evolutionary Anthropology.
# (Available online at http://wals.info/chapter/1, Accessed on 2019-06-15.)
#
# \begin{tabular}{llllllllrl}
# \toprule
# {} & wals\_code &           language &                genus &               family &                      coordinates &   \_1A\_area &                  \_1A &  \_1A\_num &          \_1A\_desc \\
# \midrule
# 0 &       kiw &   Kiwai (Southern) &              Kiwaian &              Kiwaian &                    (-8.0, 143.5) &  Phonology &             1. Small &        1 &             Small \\
# 1 &       xoo &               !Xóõ &                   Tu &                   Tu &                    (-24.0, 21.5) &  Phonology &             5. Large &        5 &             Large \\
# 2 &       ani &              //Ani &           Khoe-Kwadi &           Khoe-Kwadi &  (-18.9166666667, 21.9166666667) &  Phonology &             5. Large &        5 &             Large \\
# 3 &       abi &             Abipón &     South Guaicuruan &           Guaicuruan &                   (-29.0, -61.0) &  Phonology &  2. Moderately small &        2 &  Moderately small \\
# 4 &       abk &             Abkhaz &  Northwest Caucasian &  Northwest Caucasian &            (43.0833333333, 41.0) &  Phonology &             5. Large &        5 &             Large \\
# 5 &       acm &           Achumawi &          Palaihnihan &                Hokan &                   (41.5, -121.0) &  Phonology &  2. Moderately small &        2 &  Moderately small \\
# 6 &       ach &               Aché &         Tupi-Guaraní &               Tupian &         (-25.25, -55.1666666667) &  Phonology &             1. Small &        1 &             Small \\
# 7 &       aco &              Acoma &              Keresan &              Keresan &  (34.9166666667, -107.583333333) &  Phonology &             5. Large &        5 &             Large \\
# 8 &       adz &             Adzera &              Oceanic &         Austronesian &                  (-6.25, 146.25) &  Phonology &  2. Moderately small &        2 &  Moderately small \\
# 9 &       agh &              Aghem &              Bantoid &          Niger-Congo &        (6.666666666669999, 10.0) &  Phonology &           3. Average &        3 &           Average \\
# \bottomrule
# \end{tabular}

# %%
w = lingtypology.datasets.Wals('1a', '2a')
w.get_df().head()
# Out:
# Citation for feature 1A:
# Ian Maddieson. 2013. Consonant Inventories.
# In: Dryer, Matthew S. & Haspelmath, Martin (eds.)
# The World Atlas of Language Structures Online.
# Leipzig: Max Planck Institute for Evolutionary Anthropology.
# (Available online at http://wals.info/chapter/1, Accessed on 2019-06-15.)
#
# Citation for feature 2A:
# Ian Maddieson. 2013. Vowel Quality Inventories.
# In: Dryer, Matthew S. & Haspelmath, Martin (eds.)
# The World Atlas of Language Structures Online.
# Leipzig: Max Planck Institute for Evolutionary Anthropology.
# (Available online at http://wals.info/chapter/2, Accessed on 2019-06-15.)
#   wals_code           language                genus               family  \
# 0       kiw   Kiwai (Southern)              Kiwaian              Kiwaian
# 1       xoo               !Xóõ                   Tu                   Tu
# 2       ani              //Ani           Khoe-Kwadi           Khoe-Kwadi
# 3       abi             Abipón     South Guaicuruan           Guaicuruan
# 4       abk             Abkhaz  Northwest Caucasian  Northwest Caucasian
#
#                        coordinates   _1A_area                  _1A  _1A_num  \
# 0                    (-8.0, 143.5)  Phonology             1. Small        1
# 1                    (-24.0, 21.5)  Phonology             5. Large        5
# 2  (-18.9166666667, 21.9166666667)  Phonology             5. Large        5
# 3                   (-29.0, -61.0)  Phonology  2. Moderately small        2
# 4            (43.0833333333, 41.0)  Phonology             5. Large        5
#
#            _1A_desc   _2A_area               _2A  _2A_num       _2A_desc
# 0             Small  Phonology  2. Average (5-6)        2  Average (5-6)
# 1             Large  Phonology  2. Average (5-6)        2  Average (5-6)
# 2             Large  Phonology  2. Average (5-6)        2  Average (5-6)
# 3  Moderately small  Phonology  2. Average (5-6)        2  Average (5-6)
# 4             Large  Phonology    1. Small (2-4)        1    Small (2-4)

# %%
df = w.get_df().head()
# Out:
# Citation for feature 1A:
# Ian Maddieson. 2013. Consonant Inventories.
# In: Dryer, Matthew S. & Haspelmath, Martin (eds.)
# The World Atlas of Language Structures Online.
# Leipzig: Max Planck Institute for Evolutionary Anthropology.
# (Available online at http://wals.info/chapter/1, Accessed on 2019-06-15.)
#
# Citation for feature 2A:
# Ian Maddieson. 2013. Vowel Quality Inventories.
# In: Dryer, Matthew S. & Haspelmath, Martin (eds.)
# The World Atlas of Language Structures Online.
# Leipzig: Max Planck Institute for Evolutionary Anthropology.
# (Available online at http://wals.info/chapter/2, Accessed on 2019-06-15.)

# %%
new_df = df[['language', '_1A', '_2A']]
print(new_df.to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
# {} &           language &                  \_1A &               \_2A \\
# \midrule
# 0 &   Kiwai (Southern) &             1. Small &  2. Average (5-6) \\
# 1 &               !Xóõ &             5. Large &  2. Average (5-6) \\
# 2 &              //Ani &             5. Large &  2. Average (5-6) \\
# 3 &             Abipón &  2. Moderately small &  2. Average (5-6) \\
# 4 &             Abkhaz &             5. Large &    1. Small (2-4) \\
# \bottomrule
# \end{tabular}

# %%
df = w.get_df(join_how='outer').head()
# Out:
# Citation for feature 1A:
# Ian Maddieson. 2013. Consonant Inventories.
# In: Dryer, Matthew S. & Haspelmath, Martin (eds.)
# The World Atlas of Language Structures Online.
# Leipzig: Max Planck Institute for Evolutionary Anthropology.
# (Available online at http://wals.info/chapter/1, Accessed on 2019-06-15.)
#
# Citation for feature 2A:
# Ian Maddieson. 2013. Vowel Quality Inventories.
# In: Dryer, Matthew S. & Haspelmath, Martin (eds.)
# The World Atlas of Language Structures Online.
# Leipzig: Max Planck Institute for Evolutionary Anthropology.
# (Available online at http://wals.info/chapter/2, Accessed on 2019-06-15.)

# %%
p = lingtypology.datasets.Phoible(subset='SPA')
df = p.get_df(strip_na=['tones'])
m = lingtypology.LingMap(df.language)
m.add_features(df.tones, numeric=True)
m.colormap_colors = ('white', 'red')
m.legend_title = 'Tones'
m.legend_position = 'bottomleft'
m.create_map()
# Out:
# Moran, Steven & McCloy, Daniel (eds.) 2019.
# PHOIBLE 2.0.
# Jena: Max Planck Institute for the Science of Human History.
# (Available online at http://phoible.org, Accessed on 2019-06-16.)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas

# %%
upsid = lingtypology.datasets.Phoible(subset='UPSID', aggregated=False).get_df()
# Out:
# Moran, Steven & McCloy, Daniel (eds.) 2019.
# PHOIBLE 2.0.
# Jena: Max Planck Institute for the Science of Human History.
# (Available online at http://phoible.org, Accessed on 2019-06-16.)

# %%
amount_of_ejectives = upsid[upsid.raisedLarynxEjective == '+'].groupby('Glottocode').size()
languages = [lingtypology.glottolog.get_by_glot_id(glot_id) \
             for glot_id in amount_of_ejectives.index]
upsid_ejectives = pandas.DataFrame({
    'language': languages,
    'ejectives': amount_of_ejectives,
    'elevation': lingtypology.get_elevations(languages),
})
m = lingtypology.LingMap(upsid_ejectives.language)
m.add_features(upsid_ejectives.elevation, numeric=True)
m.create_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
