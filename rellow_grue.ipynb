# %%
import lingtypology

# %%
w = lingtypology.db_apis.Wals('134a')
w.show_citation = False
data = w.get_df()
#data.dropna(subset=['_134A'], inplace=True)
data
# Out:
#     wals_code              language                       genus  \
# 0         abd                Abidji                         Kwa
# 1         aga               Agarabi           Eastern Highlands
# 2         agc        Agta (Central)  Greater Central Philippine
# 3         agu             Aguacatec                       Mayan
# 4         amk            Amarakaeri                   Harakmbet
# 5         ape               Ampeeli                       Angan
# 6         amz                Amuzgo                    Amuzgoan
# 7         ant             Angaatiha                       Angan
# 8         api               Apinayé                 Ge-Kaingang
# 9         arb               Arabela                    Zaparoan
# 10        arl     Arabic (Lebanese)                     Semitic
# 11        bhn              Bahinemo                  Sepik Hill
# 12        bzi                 Bauzi           East Geelvink Bay
# 13        brk                 Berik                         Tor
# ...
