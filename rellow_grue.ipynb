# %%
import lingtypology
import pandas

# %%
w = lingtypology.db_apis.Wals('134a', '135a')
w.show_citation = False
data = w.get_df()
#data.dropna(subset=['_134A'], inplace=True)
data.head()
# Out:
#   wals_code        language                       genus            family  \
# 0       abd          Abidji                         Kwa       Niger-Congo
# 1       aga         Agarabi           Eastern Highlands  Trans-New Guinea
# 2       agc  Agta (Central)  Greater Central Philippine      Austronesian
# 3       agu       Aguacatec                       Mayan             Mayan
# 4       amk      Amarakaeri                   Harakmbet         Harakmbet
#
#       area                           coordinates          _134A  _134A_num  \
# 0  Lexicon   (5.666666666669999, -4.58333333333)  2. Green/blue          2
# 1  Lexicon           (-6.166666666669999, 146.0)  2. Green/blue          2
# 2  Lexicon        (17.9666666667, 121.833333333)  2. Green/blue          2
# 3  Lexicon  (15.416666666700001, -91.3333333333)  2. Green/blue          2
# 4  Lexicon                        (-12.5, -70.5)  2. Green/blue          2
#
#    _134A_desc              _135A  _135A_num      _135A_desc
# ...

# %%
red_yellow_only = data[data._135A_desc == 'Red/yellow']
grue_only = data[data._134A_desc.str.contains('reen/blue')]
#df = pandas.merge(red_yellow_only, grue_only, how='outer',
#                  on=['wals_code', 'language', 'genus', 'family', 'area', 'coordinates'])
red_yellow_only
# Out:
#     wals_code              language                genus       family  \
# 0         abd                Abidji                  Kwa  Niger-Congo
# 16        bet                  Bété                  Kru  Niger-Congo
# 19        cax      Campa (Axininca)  Pre-Andine Arawakan     Arawakan
# 29        cbo               Chácobo               Panoan       Panoan
# 33        dan                   Dan        Eastern Mande        Mande
# 36        eja               Ejagham              Bantoid  Niger-Congo
# 46        gun                  Gunu              Bantoid  Niger-Congo
# 59        kkb              Konkomba                  Gur  Niger-Congo
# 80        mdu                 Mündü               Ubangi  Niger-Congo
# 81        naf              Nafaanra                  Gur  Niger-Congo
# 89        prh                Pirahã                 Mura         Mura
# 99        tac                Tacana              Tacanan      Tacanan
# ...
